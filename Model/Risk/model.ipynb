# %%
from faker import Faker
import pandas as pd
import random

# Initialize Faker
fake = Faker()

# Define scoring system
score_mapping = {
    'Short-term': 1,
    'Medium-term': 3,
    'Long-term': 5,
    'Very comfortable': 5,
    'Somewhat comfortable': 4,
    'Neutral': 3,
    'Somewhat uncomfortable': 2,
    'Very uncomfortable': 1,
    'Advanced': 5,
    'Intermediate': 3,
    'Beginner': 1,
    'Capital growth': 5,
    'Wealth preservation': 3,
    'Income generation': 4,
    'Stay the course and hold onto investments': 5,
    'Reevaluate and potentially adjust the investment strategy': 3,
    'Sell investments to limit further losses': 1
}

# Calculate risk capacity based on scores
def calculate_risk_capacity(row):
    total_score = (
        score_mapping[row['investment_time_horizon']] +
        score_mapping[row['comfort_with_fluctuations']] +
        score_mapping[row['investment_experience']] +
        score_mapping[row['financial_goals']] +
        score_mapping[row['reaction_to_losses']]
    )
    return (
        'Conservative' if 10 <= total_score <= 16 else
        'Moderate' if 16 <= total_score <= 25 else
        'Aggressive'
    )

# Generate dummy data
num_rows = 5000
dummy_data = []

for _ in range(num_rows):
    row = {
        'investment_time_horizon': random.choice(investment_time_horizon_choices),
        'comfort_with_fluctuations': random.choice(comfort_with_fluctuations_choices),
        'investment_experience': random.choice(investment_experience_choices),
        'financial_goals': random.choice(financial_goals_choices),
        'reaction_to_losses': random.choice(reaction_to_losses_choices)
    }
    dummy_data.append(row)

# Create DataFrame
df = pd.DataFrame(dummy_data)

# Apply risk capacity function to calculate the target column
df['risk_capacity'] = df.apply(calculate_risk_capacity, axis=1)

# Calculate accuracy
accuracy = df[df['risk_capacity'] == df['risk_capacity'].mode()[0]].shape[0] / num_rows * 100

# Display accuracy
print(f"Generated dataset with {accuracy:.2f}% accuracy for the target column (risk capacity).")
# Out:
# Generated dataset with 53.18% accuracy for the target column (risk capacity).

# %%
df.head(50)
# Out:
#    investment_time_horizon comfort_with_fluctuations investment_experience  \
# 0              Medium-term                   Neutral              Beginner
# 1               Short-term    Somewhat uncomfortable              Advanced
# 2               Short-term      Somewhat comfortable              Beginner
# 3                Long-term          Very comfortable              Beginner
# 4               Short-term      Somewhat comfortable          Intermediate
# 5              Medium-term      Somewhat comfortable              Beginner
# 6                Long-term      Somewhat comfortable          Intermediate
# 7              Medium-term        Very uncomfortable              Beginner
# 8              Medium-term          Very comfortable              Advanced
# 9              Medium-term          Very comfortable              Beginner
# 10             Medium-term          Very comfortable          Intermediate
# 11               Long-term                   Neutral              Advanced
# 12             Medium-term        Very uncomfortable              Beginner
# 13             Medium-term                   Neutral          Intermediate
# 14               Long-term                   Neutral              Advanced
# 15              Short-term          Very comfortable          Intermediate
# 16              Short-term          Very comfortable              Beginner
# 17             Medium-term          Very comfortable          Intermediate
# 18             Medium-term          Very comfortable              Beginner
# 19               Long-term      Somewhat comfortable          Intermediate
# 20               Long-term        Very uncomfortable              Beginner
# 21              Short-term          Very comfortable              Beginner
# 22             Medium-term    Somewhat uncomfortable          Intermediate
# 23               Long-term    Somewhat uncomfortable              Advanced
# 24               Long-term                   Neutral          Intermediate
# 25              Short-term        Very uncomfortable          Intermediate
# 26              Short-term          Very comfortable              Beginner
# 27               Long-term      Somewhat comfortable              Advanced
# 28              Short-term        Very uncomfortable              Beginner
# 29               Long-term        Very uncomfortable              Advanced
# 30             Medium-term          Very comfortable          Intermediate
# 31             Medium-term          Very comfortable          Intermediate
# 32              Short-term        Very uncomfortable              Advanced
# 33               Long-term          Very comfortable              Beginner
# 34               Long-term                   Neutral              Advanced
# 35              Short-term                   Neutral              Beginner
# 36               Long-term                   Neutral              Advanced
# 37             Medium-term      Somewhat comfortable          Intermediate
# 38               Long-term                   Neutral              Beginner
# 39               Long-term    Somewhat uncomfortable              Advanced
# 40             Medium-term          Very comfortable          Intermediate
# 41             Medium-term      Somewhat comfortable          Intermediate
# 42              Short-term    Somewhat uncomfortable              Beginner
# 43             Medium-term          Very comfortable              Beginner
# 44               Long-term        Very uncomfortable              Beginner
# 45               Long-term      Somewhat comfortable          Intermediate
# 46               Long-term        Very uncomfortable              Advanced
# 47               Long-term    Somewhat uncomfortable          Intermediate
# 48             Medium-term      Somewhat comfortable          Intermediate
# 49              Short-term                   Neutral              Advanced
#
#         financial_goals                                 reaction_to_losses  \
# 0   Wealth preservation  Reevaluate and potentially adjust the investme...
# 1     Income generation          Stay the course and hold onto investments
# 2     Income generation           Sell investments to limit further losses
# 3        Capital growth           Sell investments to limit further losses
# 4        Capital growth          Stay the course and hold onto investments
# 5     Income generation           Sell investments to limit further losses
# 6        Capital growth           Sell investments to limit further losses
# 7   Wealth preservation  Reevaluate and potentially adjust the investme...
# 8     Income generation           Sell investments to limit further losses
# 9     Income generation           Sell investments to limit further losses
# 10       Capital growth          Stay the course and hold onto investments
# 11  Wealth preservation           Sell investments to limit further losses
# 12    Income generation           Sell investments to limit further losses
# 13  Wealth preservation           Sell investments to limit further losses
# 14    Income generation           Sell investments to limit further losses
# 15       Capital growth          Stay the course and hold onto investments
# 16       Capital growth  Reevaluate and potentially adjust the investme...
# 17       Capital growth           Sell investments to limit further losses
# 18    Income generation          Stay the course and hold onto investments
# 19    Income generation           Sell investments to limit further losses
# 20       Capital growth          Stay the course and hold onto investments
# 21  Wealth preservation           Sell investments to limit further losses
# 22       Capital growth  Reevaluate and potentially adjust the investme...
# 23    Income generation           Sell investments to limit further losses
# 24    Income generation  Reevaluate and potentially adjust the investme...
# 25       Capital growth          Stay the course and hold onto investments
# 26    Income generation           Sell investments to limit further losses
# 27    Income generation           Sell investments to limit further losses
# 28       Capital growth  Reevaluate and potentially adjust the investme...
# 29    Income generation           Sell investments to limit further losses
# 30  Wealth preservation           Sell investments to limit further losses
# 31  Wealth preservation           Sell investments to limit further losses
# 32  Wealth preservation          Stay the course and hold onto investments
# 33    Income generation           Sell investments to limit further losses
# 34    Income generation          Stay the course and hold onto investments
# 35  Wealth preservation  Reevaluate and potentially adjust the investme...
# 36    Income generation  Reevaluate and potentially adjust the investme...
# 37  Wealth preservation           Sell investments to limit further losses
# 38    Income generation  Reevaluate and potentially adjust the investme...
# 39    Income generation           Sell investments to limit further losses
# 40    Income generation          Stay the course and hold onto investments
# 41    Income generation          Stay the course and hold onto investments
# 42    Income generation           Sell investments to limit further losses
# 43       Capital growth  Reevaluate and potentially adjust the investme...
# 44  Wealth preservation          Stay the course and hold onto investments
# 45    Income generation           Sell investments to limit further losses
# 46    Income generation          Stay the course and hold onto investments
# 47  Wealth preservation          Stay the course and hold onto investments
# 48    Income generation          Stay the course and hold onto investments
# 49  Wealth preservation  Reevaluate and potentially adjust the investme...
#
#    risk_capacity
# 0   Conservative
# 1       Moderate
# 2   Conservative
# 3       Moderate
# 4       Moderate
# 5   Conservative
# 6       Moderate
# 7   Conservative
# 8       Moderate
# 9   Conservative
# 10      Moderate
# 11      Moderate
# 12  Conservative
# 13  Conservative
# 14      Moderate
# 15      Moderate
# 16  Conservative
# 17      Moderate
# 18      Moderate
# 19      Moderate
# 20      Moderate
# 21  Conservative
# 22  Conservative
# 23      Moderate
# 24      Moderate
# 25  Conservative
# 26  Conservative
# 27      Moderate
# 28  Conservative
# 29  Conservative
# 30  Conservative
# 31  Conservative
# 32  Conservative
# 33  Conservative
# 34      Moderate
# 35  Conservative
# 36      Moderate
# 37  Conservative
# 38  Conservative
# 39      Moderate
# 40      Moderate
# 41      Moderate
# 42    Aggressive
# 43      Moderate
# 44  Conservative
# 45      Moderate
# 46      Moderate
# 47      Moderate
# 48      Moderate
# 49  Conservative
