# %%
import pandas as pd
from faker import Faker
import random

# Set up Faker
fake = Faker()

# Generate dummy data for 5000 individuals
num_individuals = 5000
data = []

for _ in range(num_individuals):
    # Investment Time Horizon
    time_horizon = random.choice(['Short-term', 'Medium-term', 'Long-term'])

    # Comfort Level with Market Fluctuations
    market_comfort = random.choice(['Very comfortable', 'Somewhat comfortable', 'Neutral', 'Somewhat uncomfortable', 'Very uncomfortable'])

    # Previous Investment Experience
    investment_experience = random.choice(['Beginner (limited or no experience)', 'Intermediate (some experience)', 'Advanced (experienced in managing a diverse portfolio)'])

    # Financial Goals
    financial_goals = random.choice(['Wealth preservation (protecting existing capital)', 'Capital growth (maximizing returns)', 'Income generation (receiving regular dividends or interest)'])

    # Reaction to Potential Losses
    potential_losses_reaction = random.choice(['Stay the course and hold onto investments', 'Reevaluate and potentially adjust the investment strategy', 'Sell investments to limit further losses'])

    # Current Financial Situation
    financial_situation = random.choice(['Comfortable (Stable income and savings)', 'Adequate (Meeting basic needs with some room for savings)', 'Strained (Meeting basic needs with little room for savings)'])

    # Knowledge of Cryptocurrency
    cryptocurrency_knowledge = random.choice(['Expert (In-depth understanding)', 'Intermediate (Some understanding)', 'Novice (Limited understanding)'])

    # Emergency Fund
    emergency_fund = random.choice(['Yes, well-prepared', 'Partially prepared', 'Not prepared'])

    # Risk Capacity
    risk_capacity_score = random.randint(10, 25)

    # Liquidity Needs
    liquidity_needs = random.choice(['No immediate need (Long-term investment horizon)', 'Medium-term (Possible need within 3-5 years)', 'Short-term (Possible need within 1-3 years)'])

    # Calculate Total Score
        # Calculate Total Score
    # Calculate Total Score
    def extract_score(string):
        try:
            return int(string.split(": ")[1].split(" ")[0])
        except (IndexError, ValueError):
            return 0

    total_score = sum([
        risk_capacity_score,
        extract_score(emergency_fund),
        extract_score(financial_situation),
        extract_score(cryptocurrency_knowledge),
        extract_score(investment_experience)
    ])



    # Determine Risk Capacity
    risk_capacity = (
        'Conservative' if 8 <= total_score <= 15 else
        'Moderate' if 15 <= total_score <= 24 else
        'Aggressive'
    )

    # Create individual's data
    individual_data = {
        'Name': fake.name(),
        'Investment Time Horizon': time_horizon,
        'Comfort Level with Market Fluctuations': market_comfort,
        'Previous Investment Experience': investment_experience,
        'Financial Goals': financial_goals,
        'Reaction to Potential Losses': potential_losses_reaction,
        'Current Financial Situation': financial_situation,
        'Knowledge of Cryptocurrency': cryptocurrency_knowledge,
        'Emergency Fund': emergency_fund,
        'Risk Capacity Score': risk_capacity_score,
        'Liquidity Needs': liquidity_needs,
        'Risk Capacity': risk_capacity
    }

    data.append(individual_data)

# Create a dataframe
df = pd.DataFrame(data)

# Save the dataframe to a CSV file
df.to_csv('investment_data.csv', index=False)

# %%
df.value_counts()
# Out:
# Name           Investment Time Horizon  Comfort Level with Market Fluctuations  Previous Investment Experience                          Financial Goals                                              Reaction to Potential Losses                               Current Financial Situation                                  Knowledge of Cryptocurrency        Emergency Fund      Risk Capacity Score  Liquidity Needs                                   Risk Capacity
# Aaron Alvarez  Short-term               Somewhat uncomfortable                  Intermediate (some experience)                          Income generation (receiving regular dividends or interest)  Sell investments to limit further losses                   Adequate (Meeting basic needs with some room for savings)    Intermediate (Some understanding)  Partially prepared  10                   Medium-term (Possible need within 3-5 years)      Conservative     1
# Megan Garza    Short-term               Neutral                                 Advanced (experienced in managing a diverse portfolio)  Wealth preservation (protecting existing capital)            Stay the course and hold onto investments                  Comfortable (Stable income and savings)                      Novice (Limited understanding)     Partially prepared  17                   No immediate need (Long-term investment horizon)  Moderate         1
# Megan Lane MD  Short-term               Somewhat comfortable                    Beginner (limited or no experience)                     Income generation (receiving regular dividends or interest)  Reevaluate and potentially adjust the investment strategy  Comfortable (Stable income and savings)                      Intermediate (Some understanding)  Yes, well-prepared  18                   Short-term (Possible need within 1-3 years)       Moderate         1
# Megan Keller   Short-term               Neutral                                 Intermediate (some experience)                          Capital growth (maximizing returns)                          Stay the course and hold onto investments                  Strained (Meeting basic needs with little room for savings)  Novice (Limited understanding)     Partially prepared  15                   Short-term (Possible need within 1-3 years)       Conservative     1
# Megan Johnson  Long-term                Somewhat uncomfortable                  Intermediate (some experience)                          Wealth preservation (protecting existing capital)            Reevaluate and potentially adjust the investment strategy  Comfortable (Stable income and savings)                      Novice (Limited understanding)     Not prepared        11                   Short-term (Possible need within 1-3 years)       Conservative     1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# Gina Thornton  Medium-term              Somewhat comfortable                    Intermediate (some experience)                          Income generation (receiving regular dividends or interest)  Sell investments to limit further losses                   Adequate (Meeting basic needs with some room for savings)    Intermediate (Some understanding)  Yes, well-prepared  24                   No immediate need (Long-term investment horizon)  Moderate         1
# Gina Parks     Long-term                Very uncomfortable                      Beginner (limited or no experience)                     Income generation (receiving regular dividends or interest)  Sell investments to limit further losses                   Strained (Meeting basic needs with little room for savings)  Expert (In-depth understanding)    Yes, well-prepared  13                   Medium-term (Possible need within 3-5 years)      Conservative     1
# Gina Odonnell  Medium-term              Very uncomfortable                      Beginner (limited or no experience)                     Capital growth (maximizing returns)                          Stay the course and hold onto investments                  Strained (Meeting basic needs with little room for savings)  Novice (Limited understanding)     Not prepared        15                   Medium-term (Possible need within 3-5 years)      Conservative     1
# Gina Martinez  Short-term               Somewhat uncomfortable                  Advanced (experienced in managing a diverse portfolio)  Capital growth (maximizing returns)                          Sell investments to limit further losses                   Adequate (Meeting basic needs with some room for savings)    Intermediate (Some understanding)  Partially prepared  21                   No immediate need (Long-term investment horizon)  Moderate         1
# Zachary Tran   Long-term                Very comfortable                        Beginner (limited or no experience)                     Income generation (receiving regular dividends or interest)  Sell investments to limit further losses                   Adequate (Meeting basic needs with some room for savings)    Novice (Limited understanding)     Partially prepared  19                   No immediate need (Long-term investment horizon)  Moderate         1
# Length: 5000, dtype: int64

# %%
df.head(20)
# Out:
#                 Name Investment Time Horizon  \
# 0   Benjamin Stevens              Short-term
# 1   Cynthia Richards             Medium-term
# 2     Kara Blanchard              Short-term
# 3       Timothy Ford               Long-term
# 4        Wayne Sharp               Long-term
# 5        Tyler Terry               Long-term
# 6         April King              Short-term
# 7       Taylor Myers               Long-term
# 8       Gary Sanchez              Short-term
# 9     Adrienne Ayala              Short-term
# 10      Amanda Casey              Short-term
# 11    William Krause               Long-term
# 12     Albert Malone             Medium-term
# 13     Robert Butler               Long-term
# 14   Debra Rodriguez             Medium-term
# 15    Carolyn Campos              Short-term
# 16    James Williams               Long-term
# 17       Ashley Bond               Long-term
# 18    Gregory Curtis               Long-term
# 19     Travis Vargas             Medium-term
#
#    Comfort Level with Market Fluctuations  \
# 0                      Very uncomfortable
# 1                        Very comfortable
# 2                                 Neutral
# 3                  Somewhat uncomfortable
# 4                        Very comfortable
# 5                                 Neutral
# 6                      Very uncomfortable
# 7                        Very comfortable
# 8                  Somewhat uncomfortable
# 9                      Very uncomfortable
# 10                   Somewhat comfortable
# 11                 Somewhat uncomfortable
# 12                     Very uncomfortable
# 13                                Neutral
# 14                       Very comfortable
# 15                 Somewhat uncomfortable
# 16                   Somewhat comfortable
# 17                     Very uncomfortable
# 18                     Very uncomfortable
# 19                     Very uncomfortable
#
#                        Previous Investment Experience  \
# 0                 Beginner (limited or no experience)
# 1                      Intermediate (some experience)
# 2                      Intermediate (some experience)
# 3                 Beginner (limited or no experience)
# 4                      Intermediate (some experience)
# 5                      Intermediate (some experience)
# 6   Advanced (experienced in managing a diverse po...
# 7   Advanced (experienced in managing a diverse po...
# 8   Advanced (experienced in managing a diverse po...
# 9   Advanced (experienced in managing a diverse po...
# 10                     Intermediate (some experience)
# 11                Beginner (limited or no experience)
# 12                Beginner (limited or no experience)
# 13                     Intermediate (some experience)
# 14  Advanced (experienced in managing a diverse po...
# 15                     Intermediate (some experience)
# 16                Beginner (limited or no experience)
# 17                Beginner (limited or no experience)
# 18                Beginner (limited or no experience)
# 19  Advanced (experienced in managing a diverse po...
#
#                                       Financial Goals  \
# 0   Income generation (receiving regular dividends...
# 1   Income generation (receiving regular dividends...
# 2                 Capital growth (maximizing returns)
# 3                 Capital growth (maximizing returns)
# 4   Income generation (receiving regular dividends...
# 5   Wealth preservation (protecting existing capital)
# 6   Income generation (receiving regular dividends...
# 7   Wealth preservation (protecting existing capital)
# 8   Income generation (receiving regular dividends...
# 9   Wealth preservation (protecting existing capital)
# 10  Wealth preservation (protecting existing capital)
# 11  Wealth preservation (protecting existing capital)
# 12  Wealth preservation (protecting existing capital)
# 13  Wealth preservation (protecting existing capital)
# 14                Capital growth (maximizing returns)
# 15  Wealth preservation (protecting existing capital)
# 16  Income generation (receiving regular dividends...
# 17  Wealth preservation (protecting existing capital)
# 18                Capital growth (maximizing returns)
# 19                Capital growth (maximizing returns)
#
#                          Reaction to Potential Losses  \
# 0            Sell investments to limit further losses
# 1            Sell investments to limit further losses
# 2            Sell investments to limit further losses
# 3            Sell investments to limit further losses
# 4            Sell investments to limit further losses
# 5   Reevaluate and potentially adjust the investme...
# 6   Reevaluate and potentially adjust the investme...
# 7   Reevaluate and potentially adjust the investme...
# 8            Sell investments to limit further losses
# 9           Stay the course and hold onto investments
# 10           Sell investments to limit further losses
# 11           Sell investments to limit further losses
# 12  Reevaluate and potentially adjust the investme...
# 13          Stay the course and hold onto investments
# 14          Stay the course and hold onto investments
# 15           Sell investments to limit further losses
# 16          Stay the course and hold onto investments
# 17          Stay the course and hold onto investments
# 18  Reevaluate and potentially adjust the investme...
# 19           Sell investments to limit further losses
#
#                           Current Financial Situation  \
# 0   Adequate (Meeting basic needs with some room f...
# 1   Strained (Meeting basic needs with little room...
# 2   Adequate (Meeting basic needs with some room f...
# 3   Strained (Meeting basic needs with little room...
# 4   Adequate (Meeting basic needs with some room f...
# 5   Strained (Meeting basic needs with little room...
# 6             Comfortable (Stable income and savings)
# 7   Adequate (Meeting basic needs with some room f...
# 8             Comfortable (Stable income and savings)
# 9   Adequate (Meeting basic needs with some room f...
# 10  Strained (Meeting basic needs with little room...
# 11  Strained (Meeting basic needs with little room...
# 12  Adequate (Meeting basic needs with some room f...
# 13  Adequate (Meeting basic needs with some room f...
# 14  Adequate (Meeting basic needs with some room f...
# 15            Comfortable (Stable income and savings)
# 16  Strained (Meeting basic needs with little room...
# 17            Comfortable (Stable income and savings)
# 18  Strained (Meeting basic needs with little room...
# 19            Comfortable (Stable income and savings)
#
#           Knowledge of Cryptocurrency      Emergency Fund  \
# 0     Expert (In-depth understanding)  Partially prepared
# 1   Intermediate (Some understanding)  Partially prepared
# 2   Intermediate (Some understanding)  Yes, well-prepared
# 3      Novice (Limited understanding)        Not prepared
# 4   Intermediate (Some understanding)  Partially prepared
# 5   Intermediate (Some understanding)  Yes, well-prepared
# 6      Novice (Limited understanding)  Yes, well-prepared
# 7      Novice (Limited understanding)        Not prepared
# 8   Intermediate (Some understanding)  Yes, well-prepared
# 9      Novice (Limited understanding)        Not prepared
# 10    Expert (In-depth understanding)        Not prepared
# 11     Novice (Limited understanding)  Yes, well-prepared
# 12     Novice (Limited understanding)  Partially prepared
# 13    Expert (In-depth understanding)  Yes, well-prepared
# 14     Novice (Limited understanding)  Partially prepared
# 15    Expert (In-depth understanding)  Partially prepared
# 16     Novice (Limited understanding)  Yes, well-prepared
# 17     Novice (Limited understanding)  Yes, well-prepared
# 18     Novice (Limited understanding)        Not prepared
# 19     Novice (Limited understanding)        Not prepared
#
#     Risk Capacity Score                                   Liquidity Needs  \
# 0                    20  No immediate need (Long-term investment horizon)
# 1                    16      Medium-term (Possible need within 3-5 years)
# 2                    10      Medium-term (Possible need within 3-5 years)
# 3                    13      Medium-term (Possible need within 3-5 years)
# 4                    10      Medium-term (Possible need within 3-5 years)
# 5                    19      Medium-term (Possible need within 3-5 years)
# 6                    24       Short-term (Possible need within 1-3 years)
# 7                    21  No immediate need (Long-term investment horizon)
# 8                    15      Medium-term (Possible need within 3-5 years)
# 9                    14  No immediate need (Long-term investment horizon)
# 10                   10       Short-term (Possible need within 1-3 years)
# 11                   15       Short-term (Possible need within 1-3 years)
# 12                   23  No immediate need (Long-term investment horizon)
# 13                   22  No immediate need (Long-term investment horizon)
# 14                   16       Short-term (Possible need within 1-3 years)
# 15                   14  No immediate need (Long-term investment horizon)
# 16                   11       Short-term (Possible need within 1-3 years)
# 17                   10      Medium-term (Possible need within 3-5 years)
# 18                   14      Medium-term (Possible need within 3-5 years)
# 19                   11  No immediate need (Long-term investment horizon)
#
#    Risk Capacity
# 0       Moderate
# 1       Moderate
# 2   Conservative
# 3   Conservative
# 4   Conservative
# 5       Moderate
# 6       Moderate
# 7       Moderate
# 8   Conservative
# 9   Conservative
# 10  Conservative
# 11  Conservative
# 12      Moderate
# 13      Moderate
# 14      Moderate
# 15  Conservative
# 16  Conservative
# 17  Conservative
# 18  Conservative
# 19  Conservative

# %%
df.drop('Name',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Investment Time Horizon Comfort Level with Market Fluctuations  \
# 0              Short-term                     Very uncomfortable
# 1             Medium-term                       Very comfortable
# 2              Short-term                                Neutral
# 3               Long-term                 Somewhat uncomfortable
# 4               Long-term                       Very comfortable
#
#         Previous Investment Experience  \
# 0  Beginner (limited or no experience)
# 1       Intermediate (some experience)
# 2       Intermediate (some experience)
# 3  Beginner (limited or no experience)
# 4       Intermediate (some experience)
#
#                                      Financial Goals  \
# 0  Income generation (receiving regular dividends...
# 1  Income generation (receiving regular dividends...
# 2                Capital growth (maximizing returns)
# 3                Capital growth (maximizing returns)
# 4  Income generation (receiving regular dividends...
#
#                Reaction to Potential Losses  \
# 0  Sell investments to limit further losses
# 1  Sell investments to limit further losses
# 2  Sell investments to limit further losses
# 3  Sell investments to limit further losses
# 4  Sell investments to limit further losses
#
#                          Current Financial Situation  \
# 0  Adequate (Meeting basic needs with some room f...
# 1  Strained (Meeting basic needs with little room...
# 2  Adequate (Meeting basic needs with some room f...
# 3  Strained (Meeting basic needs with little room...
# 4  Adequate (Meeting basic needs with some room f...
#
#          Knowledge of Cryptocurrency      Emergency Fund  Risk Capacity Score  \
# 0    Expert (In-depth understanding)  Partially prepared                   20
# 1  Intermediate (Some understanding)  Partially prepared                   16
# 2  Intermediate (Some understanding)  Yes, well-prepared                   10
# 3     Novice (Limited understanding)        Not prepared                   13
# 4  Intermediate (Some understanding)  Partially prepared                   10
#
#                                     Liquidity Needs Risk Capacity
# 0  No immediate need (Long-term investment horizon)      Moderate
# 1      Medium-term (Possible need within 3-5 years)      Moderate
# 2      Medium-term (Possible need within 3-5 years)  Conservative
# 3      Medium-term (Possible need within 3-5 years)  Conservative
# 4      Medium-term (Possible need within 3-5 years)  Conservative

# %%
file_path = 'investment_data.csv'
df = pd.read_csv(file_path)

# Drop the 'Name' column
df = df.drop('Name', axis=1)

# Encode categorical variables using one-hot encoding
encoder = OneHotEncoder(cols=['Investment Time Horizon', 'Comfort Level with Market Fluctuations',
                               'Previous Investment Experience', 'Financial Goals',
                               'Reaction to Potential Losses', 'Current Financial Situation',
                               'Knowledge of Cryptocurrency', 'Emergency Fund', 'Liquidity Needs',
                               'Risk Capacity'])
df_encoded = encoder.fit_transform(df)

# %%
df_encoded.shape
# Out:
# (5000, 33)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=2)

# %%
from statistics import LinearRegression
from sklearn.compose import ColumnTransformer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder


step1= ColumnTransformer(transformers=
        [('col_tnf', OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],
        remainder='passthrough'
        )

step2=LinearRegression()

pipe=Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 13
#       5 from sklearn.preprocessing import OneHotEncoder
#       8 step1= ColumnTransformer(transformers=
#       9         [('col_tnf', OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])],
#      10         remainder='passthrough'
#      11         )
# ---> 13 step2=LinearRegression()
#      15 pipe=Pipeline([
#      16     ('step1',step1),
#      17     ('step2',step2)
#      18 ])
#      20 pipe.fit(X_train,y_train)
#
# TypeError: LinearRegression.__new__() missing 2 required positional arguments: 'slope' and 'intercept'
